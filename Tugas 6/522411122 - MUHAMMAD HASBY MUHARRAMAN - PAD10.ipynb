# %%
# 5220411122
# MUHAMMAD HASBY MUHARRAMAN

# %%
# import library 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] = 14
plt.rcParams['font.weight'] = 'bold'
plt.style.use('seaborn-v0_8-whitegrid')

# %%
path = '../input/'

df = pd.read_csv('Heart_Disease_Prediction.csv')

print(f'\nNumber of rows and columns in the dataset:\n{df.shape}')
print('')
df.head()
# Out:
# Number of rows and columns in the dataset:
# (270, 14)
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...

# %%
sns.lmplot(x='BP', y='Max HR', data=df, aspect=2, height=6)
plt.xlabel('Blood Pressure$(mmHg)$: as Independent Variable')
plt.ylabel('Max Heart Rate as Dependent Variable')
plt.title('BP VS Max HR')
# Out:
# Text(0.5, 1.0, 'BP VS Max HR')

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.isnull(),cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Value in the Dataset')
# Out:
# Text(0.5, 1.0, 'Missing Value in the Dataset')

# %%
#correlation plot
plt.figure(figsize=(16,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, cmap='viridis', annot=True);

# %%
# Distribution Plot
f = plt.figure(figsize=(14,4))

ax =f.add_subplot(121)
sns.distplot(df['BP'], bins=50, color='r', ax=ax)
ax.set_title('Distribution of Blood Pressure')

ax =f.add_subplot(122)
sns.distplot(np.log10(df['BP']), bins=40, color='y', ax=ax)
ax.set_title('Distribution of Blood Pressure on $log$ scale')
ax.set_xscale('log');
# Out:
# /tmp/ipykernel_17371/1011211330.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BP'], bins=50, color='r', ax=ax)
# /tmp/ipykernel_17371/1011211330.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log10(df['BP']), bins=40, color='y', ax=ax)

# %%
# Violin Plot
f = plt.figure(figsize=(10,4))

f = plt.figure(figsize=(10, 4))

ax = f.add_subplot(121)
sns.violinplot(data=df, x='Chest pain type', y='Cholesterol', hue='Chest pain type', palette='Wistia', ax=ax, legend=False)
ax.set_title('Violin Plot of Chest Pain Type vs Cholesterol')

ax = f.add_subplot(122)
sns.violinplot(data=df, x='Heart Disease', y='Age', hue='Heart Disease', palette='magma', ax=ax, legend=False)
ax.set_title('Violin Plot of Heart Disease vs Age')
# Out:
# Text(0.5, 1.0, 'Violin Plot of Heart Disease vs Age')

# %%
# Box Plot
sns.boxplot(data=df, x='Chest pain type',y='BP', palette='Wistia', hue='Sex')
ax.set_title('Box Plot of Chest Pain Type vs Blood Pleasure')
# Out:
# Text(0.5, 1.0, 'Box Plot of Chest Pain Type vs Blood Pleasure')

# %%
result = df.groupby('Chest pain type').agg({'Max HR': ['mean', 'min', 'max']})
print(result)
# Out:
#                      Max HR
#                        mean  min  max
# Chest pain type
# 1                156.900000  114  190
# 2                161.547619  103  202
# 3                155.379747   96  194
# 4                141.201550   71  186

# %%
plt.figure(figsize=(10,6))
sns.violinplot(data=df, x='Heart Disease',y='Cholesterol', hue='Sex',palette='rainbow', split=True)
ax.set_title('Violin Plot of Heart Disease vs Cholesterol')
# Out:
# Text(0.5, 1.0, 'Violin Plot of Heart Disease vs Cholesterol')

# %%
f = plt.figure(figsize=(12,6))
ax = f.add_subplot(121)
sns.scatterplot(data=df, x='Cholesterol',y='Max HR', hue='Heart Disease',palette='magma', ax=ax)
ax.set_title('Scatter Plot of Max HR vs Cholesterol')

ax =f.add_subplot(122)
sns.scatterplot(data=df, x='BP',y='Max HR', hue='Heart Disease',palette='viridis', ax=ax)
ax.set_title('Scatter Plot of Max HR vs BP');

plt.savefig('Sc.png')
